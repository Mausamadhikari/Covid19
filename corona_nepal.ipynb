# %%
#importing numpy library for numeric python stuffs
#pandas for using data in dataframe 
#matplotlib.pyplot for ploting for visual representation
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#loading csv data to a variable from owid 
url_for_data = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

# %%
#reading data from csv format and converting to dataframe and viewing top 5 data
data = pd.read_csv(url_for_data)
data.head()
# Out:
#   iso_code      continent  ... life_expectancy human_development_index
# 0      ABW  North America  ...           76.29                     NaN
# 1      ABW  North America  ...           76.29                     NaN
# 2      ABW  North America  ...           76.29                     NaN
# 3      ABW  North America  ...           76.29                     NaN
# 4      ABW  North America  ...           76.29                     NaN
#
# [5 rows x 41 columns]

# %%
#selecting country nepal
country_nepal = data[data.location == "Nepal"]

# %%
#viewing data for viewing no of rows and columns
country_nepal
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 35027      NPL      Asia  ...           70.78                   0.574
# 35028      NPL      Asia  ...           70.78                   0.574
# 35029      NPL      Asia  ...           70.78                   0.574
# 35030      NPL      Asia  ...           70.78                   0.574
# 35031      NPL      Asia  ...           70.78                   0.574
# ...        ...       ...  ...             ...                     ...
# 35313      NPL      Asia  ...           70.78                   0.574
# 35314      NPL      Asia  ...           70.78                   0.574
# 35315      NPL      Asia  ...           70.78                   0.574
# 35316      NPL      Asia  ...           70.78                   0.574
# 35317      NPL      Asia  ...           70.78                   0.574
#
# [291 rows x 41 columns]

# %%
#checking nan value if there are any
country_nepal.isna().any()
# Out:
# iso_code                           False
# continent                          False
# location                           False
# date                               False
# total_cases                         True
# new_cases                           True
# new_cases_smoothed                  True
# total_deaths                        True
# new_deaths                          True
# new_deaths_smoothed                 True
# total_cases_per_million             True
# new_cases_per_million               True
# new_cases_smoothed_per_million      True
# total_deaths_per_million            True
# new_deaths_per_million              True
# new_deaths_smoothed_per_million     True
# new_tests                           True
# total_tests                         True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_per_case                      True
# ...

# %%
#no of nan value in columns
country_nepal.isna().sum()
# Out:
# iso_code                             0
# continent                            0
# location                             0
# date                                 0
# total_cases                         38
# new_cases                           13
# new_cases_smoothed                   6
# total_deaths                       138
# new_deaths                          13
# new_deaths_smoothed                  6
# total_cases_per_million             38
# new_cases_per_million               13
# new_cases_smoothed_per_million       6
# total_deaths_per_million           138
# new_deaths_per_million              13
# new_deaths_smoothed_per_million      6
# new_tests                           66
# total_tests                         53
# total_tests_per_thousand            53
# new_tests_per_thousand              66
# new_tests_smoothed                  36
# new_tests_smoothed_per_thousand     36
# tests_per_case                      85
# positive_rate                       36
# ...

# %%
#importing seaborn 
import seaborn as sns

# %%
# plotting date vs total cases to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_cases',data = country_nepal)
plt.show()

# %%
# plotting date vs total tests to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_tests',data = country_nepal)
plt.show()

# %%
# plotting date vs new tests to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='new_tests',data = country_nepal)
plt.show()

# %%
# plotting date vs total deaths to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_deaths',data = country_nepal)
plt.show()

# %%
# plotting date vs new deaths to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='new_deaths',data = country_nepal)
plt.show()

# %%
# plotting date vs positivr rate to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='positive_rate',data = country_nepal)
plt.show()

# %%
# plotting total test vs total cases to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='total_tests',y='total_cases',data = country_nepal)
plt.show()

# %%
# plotting total tests vs total deaths to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='total_tests',y='total_deaths',data = country_nepal)
plt.show()

# %%
# plotting new tests vs new deaths to analyze the data plot
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='new_tests',y='new_deaths',data = country_nepal)
plt.show()

# %%
#viewing last 5 data 
country_nepal.tail()
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 35313      NPL      Asia  ...           70.78                   0.574
# 35314      NPL      Asia  ...           70.78                   0.574
# 35315      NPL      Asia  ...           70.78                   0.574
# 35316      NPL      Asia  ...           70.78                   0.574
# 35317      NPL      Asia  ...           70.78                   0.574
#
# [5 rows x 41 columns]

# %%
#dropping columns
country_nepal.drop(['continent','life_expectancy','hospital_beds_per_thousand','handwashing_facilities','male_smokers','female_smokers','diabetes_prevalence','cardiovasc_death_rate','extreme_poverty','gdp_per_capita'],axis =1 ,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
country_nepal
# Out:
#       iso_code location  ... aged_70_older  human_development_index
# 35027      NPL    Nepal  ...         3.212                    0.574
# 35028      NPL    Nepal  ...         3.212                    0.574
# 35029      NPL    Nepal  ...         3.212                    0.574
# 35030      NPL    Nepal  ...         3.212                    0.574
# 35031      NPL    Nepal  ...         3.212                    0.574
# ...        ...      ...  ...           ...                      ...
# 35313      NPL    Nepal  ...         3.212                    0.574
# 35314      NPL    Nepal  ...         3.212                    0.574
# 35315      NPL    Nepal  ...         3.212                    0.574
# 35316      NPL    Nepal  ...         3.212                    0.574
# 35317      NPL    Nepal  ...         3.212                    0.574
#
# [291 rows x 31 columns]

# %%
country_nepal.drop(['iso_code','total_cases_per_million', 
'new_cases_per_million', 
'total_deaths_per_million', 
'new_deaths_per_million'],axis =1 ,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
country_nepal.drop(['new_cases_smoothed','new_deaths_smoothed', 
'new_cases_smoothed_per_million', 
'new_deaths_smoothed_per_million', 
'total_tests_per_thousand','new_tests_per_thousand','new_tests_smoothed','new_tests_smoothed_per_thousand','stringency_index'],axis =1 ,inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
country_nepal
# Out:
#       location        date  ...  aged_70_older  human_development_index
# 35027    Nepal  2019-12-31  ...          3.212                    0.574
# 35028    Nepal  2020-01-01  ...          3.212                    0.574
# 35029    Nepal  2020-01-02  ...          3.212                    0.574
# 35030    Nepal  2020-01-03  ...          3.212                    0.574
# 35031    Nepal  2020-01-04  ...          3.212                    0.574
# ...        ...         ...  ...            ...                      ...
# 35313    Nepal  2020-10-12  ...          3.212                    0.574
# 35314    Nepal  2020-10-13  ...          3.212                    0.574
# 35315    Nepal  2020-10-14  ...          3.212                    0.574
# 35316    Nepal  2020-10-15  ...          3.212                    0.574
# 35317    Nepal  2020-10-16  ...          3.212                    0.574
#
# [291 rows x 17 columns]

# %%
# country_nepal.drop(['total_tests', 
# 'new_tests', 
# 'new_tests_smoothed', 
# 'total_tests_per_thousand', 
# 'new_tests_per_thousand', 
# 'new_tests_smoothed_per_thousand',
# 'tests_per_case', 
# 'positive_rate', 
# 'tests_units']
# ,axis =1 ,inplace=True)

# %%
country_nepal
# Out:
#       location        date  ...  aged_70_older  human_development_index
# 35027    Nepal  2019-12-31  ...          3.212                    0.574
# 35028    Nepal  2020-01-01  ...          3.212                    0.574
# 35029    Nepal  2020-01-02  ...          3.212                    0.574
# 35030    Nepal  2020-01-03  ...          3.212                    0.574
# 35031    Nepal  2020-01-04  ...          3.212                    0.574
# ...        ...         ...  ...            ...                      ...
# 35313    Nepal  2020-10-12  ...          3.212                    0.574
# 35314    Nepal  2020-10-13  ...          3.212                    0.574
# 35315    Nepal  2020-10-14  ...          3.212                    0.574
# 35316    Nepal  2020-10-15  ...          3.212                    0.574
# 35317    Nepal  2020-10-16  ...          3.212                    0.574
#
# [291 rows x 17 columns]

# %%
#calculating mean
mean = country_nepal.mean()
mean
# Out:
# total_cases                1.668717e+04
# new_cases                  4.183677e+02
# total_deaths               8.782131e+01
# new_deaths                 2.384880e+00
# new_tests                  4.252691e+03
# total_tests                2.549348e+05
# tests_per_case             5.935609e+01
# positive_rate              4.092096e-02
# population                 2.913681e+07
# population_density         2.044300e+02
# median_age                 2.500000e+01
# aged_65_older              5.809000e+00
# aged_70_older              3.212000e+00
# human_development_index    5.740000e-01
# dtype: float64

# %%
country_nepal.fillna(country_nepal.mean())
# Out:
#       location        date  ...  aged_70_older  human_development_index
# 35027    Nepal  2019-12-31  ...          3.212                    0.574
# 35028    Nepal  2020-01-01  ...          3.212                    0.574
# 35029    Nepal  2020-01-02  ...          3.212                    0.574
# 35030    Nepal  2020-01-03  ...          3.212                    0.574
# 35031    Nepal  2020-01-04  ...          3.212                    0.574
# ...        ...         ...  ...            ...                      ...
# 35313    Nepal  2020-10-12  ...          3.212                    0.574
# 35314    Nepal  2020-10-13  ...          3.212                    0.574
# 35315    Nepal  2020-10-14  ...          3.212                    0.574
# 35316    Nepal  2020-10-15  ...          3.212                    0.574
# 35317    Nepal  2020-10-16  ...          3.212                    0.574
#
# [291 rows x 17 columns]

# %%
#country_nepal.drop(['continent'],axis =1 ,inplace=True)
country_nepal.isna().sum()
# Out:
# location                   0
# date                       0
# total_cases                0
# new_cases                  0
# total_deaths               0
# new_deaths                 0
# new_tests                  0
# total_tests                0
# tests_per_case             0
# positive_rate              0
# tests_units                0
# population                 0
# population_density         0
# median_age                 0
# aged_65_older              0
# aged_70_older              0
# human_development_index    0
# dtype: int64

# %%
country_nepal = country_nepal.fillna(0)

# %%
country_nepal.isna().sum()
# Out:
# location                   0
# date                       0
# total_cases                0
# new_cases                  0
# total_deaths               0
# new_deaths                 0
# new_tests                  0
# total_tests                0
# tests_per_case             0
# positive_rate              0
# tests_units                0
# population                 0
# population_density         0
# median_age                 0
# aged_65_older              0
# aged_70_older              0
# human_development_index    0
# dtype: int64

# %%
population = data['population'].unique()

# %%
country_nepal.drop(['population'],axis =1 ,inplace=True)

# %%
country_nepal.drop(['total_tests'],axis =1 ,inplace=True)

# %%
country_nepal.plot()

# %%
country_nepal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 291 entries, 35027 to 35317
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 291 non-null    object
#  1   date                     291 non-null    object
#  2   total_cases              291 non-null    float64
#  3   new_cases                291 non-null    float64
#  4   total_deaths             291 non-null    float64
#  5   new_deaths               291 non-null    float64
#  6   new_tests                291 non-null    float64
#  7   tests_per_case           291 non-null    float64
#  8   positive_rate            291 non-null    float64
#  9   tests_units              291 non-null    object
#  10  population_density       291 non-null    float64
#  11  median_age               291 non-null    float64
#  12  aged_65_older            291 non-null    float64
# ...

# %%
data = country_nepal

# %%
data.head()
# Out:
#       location        date  ...  aged_70_older  human_development_index
# 35027    Nepal  2019-12-31  ...          3.212                    0.574
# 35028    Nepal  2020-01-01  ...          3.212                    0.574
# 35029    Nepal  2020-01-02  ...          3.212                    0.574
# 35030    Nepal  2020-01-03  ...          3.212                    0.574
# 35031    Nepal  2020-01-04  ...          3.212                    0.574
#
# [5 rows x 15 columns]

# %%
data.tail()
# Out:
#       location        date  ...  aged_70_older  human_development_index
# 35313    Nepal  2020-10-12  ...          3.212                    0.574
# 35314    Nepal  2020-10-13  ...          3.212                    0.574
# 35315    Nepal  2020-10-14  ...          3.212                    0.574
# 35316    Nepal  2020-10-15  ...          3.212                    0.574
# 35317    Nepal  2020-10-16  ...          3.212                    0.574
#
# [5 rows x 15 columns]

# %%
data['total_deaths'] =pd.to_numeric(data['total_deaths'])
data['total_cases'] = pd.to_numeric(data['total_cases'])

# %%
location = data['location'].unique()
median_age = data['median_age'].unique()
population_density = data['population_density'].unique()
human_development_index = data['human_development_index'].unique()

# %%
print(location,
median_age,
population_density,
human_development_index)
# Out:
# ['Nepal'] [25.] [204.43] [0.574]

# %%
from sklearn.linear_model import LinearRegression as lr
from sklearn.model_selection import train_test_split
import datetime as dt

data['date'] = pd.to_datetime(data['date'])
data['date'] = data['date'].map(dt.datetime.toordinal)
data.head()
# Out:
#       location    date  ...  aged_70_older  human_development_index
# 35027    Nepal  737424  ...          3.212                    0.574
# 35028    Nepal  737425  ...          3.212                    0.574
# 35029    Nepal  737426  ...          3.212                    0.574
# 35030    Nepal  737427  ...          3.212                    0.574
# 35031    Nepal  737428  ...          3.212                    0.574
#
# [5 rows x 15 columns]

# %%
x = data['date']
y = data['total_cases']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
linear_reg = lr()

# %%
linear_reg.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
data.tail()
# Out:
#       location    date  ...  aged_70_older  human_development_index
# 35313    Nepal  737710  ...          3.212                    0.574
# 35314    Nepal  737711  ...          3.212                    0.574
# 35315    Nepal  737712  ...          3.212                    0.574
# 35316    Nepal  737713  ...          3.212                    0.574
# 35317    Nepal  737714  ...          3.212                    0.574
#
# [5 rows x 15 columns]

# %%
y_pred = linear_reg.predict(np.array(x_test).reshape(-1,1))

# %%
data.isna().any()
# Out:
# location                   False
# date                       False
# total_cases                False
# new_cases                  False
# total_deaths               False
# new_deaths                 False
# new_tests                  False
# tests_per_case             False
# positive_rate              False
# tests_units                False
# population_density         False
# median_age                 False
# aged_65_older              False
# aged_70_older              False
# human_development_index    False
# dtype: bool

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 514562419353.9949

# %%
linear_reg.predict(np.array([[737712]]))
# Out:
# array([[53221.06114334]])
